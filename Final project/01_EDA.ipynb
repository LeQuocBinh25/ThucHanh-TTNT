# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# đọc dataset
columns = ['variance','skewness','curtosis','entropy','class']
df = pd.read_csv('banknote_authentication.csv', names=columns)

print("===== HEAD =====")
print(df.head())

print("\n===== SHAPE =====")
print(df.shape)

print("\n===== INFO =====")
print(df.info())

print("\n===== COLUMNS =====")
print(df.columns)

print("\n===== MISSING VALUES =====")
print(df.isnull().sum())

print("\n===== DUPLICATED VALUES =====")
print(df.duplicated().sum())

print("\n===== STATISTICAL SUMMARY =====")
print(df.describe())

print("\n===== TARGET DISTRIBUTION =====")
print(df['class'].value_counts())

# histogram
print("\n===== HISTOGRAM =====")
df.hist(figsize=(10,8))
plt.show()

# correlation matrix
print("\n===== CORRELATION MATRIX =====")
corr = df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# boxplot phát hiện outlier
print("\n===== OUTLIER DETECTION =====")
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.show()
# Out:
# Running cells with 'Python 3.12.12' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/msys64/ucrt64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'
